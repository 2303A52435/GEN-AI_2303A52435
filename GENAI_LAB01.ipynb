# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A52435/GEN-AI_2303A52435/blob/main/GENAI_LAB01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ASSIGNMENT-2

# %% [markdown]
# Q1

# %% [markdown]
# ![WhatsApp Image 2025-01-17 at 13.37.09_515c170a.jpg](data:image/jpeg;base64,...)

# %%
from scipy.optimize import linprog

# %%
c = [-6, -5]

# %%
A = [
    [1, 1],     # Milk constraint: x + y <= 5
    [3, 2]      # Choco constraint: 3x + 2y <= 12
]
b = [5, 12]

# %%
x_bounds = (0, None)
y_bounds = (0, None)

# %%
result = linprog(c, A_ub=A, b_ub=b, bounds=[x_bounds, y_bounds], method='highs')

# %%
if result.success:
    print(f"Optimal number of chocolate A (x): {result.x[0]:.2f}")
    print(f"Optimal number of chocolate B (y): {result.x[1]:.2f}")
    print(f"Maximum profit: {-result.fun:.2f}")  # Negative because we minimized -Z
else:
    print("No solution found.")
# Out:
# Optimal number of chocolate A (x): 2.00
# Optimal number of chocolate B (y): 3.00
# Maximum profit: 27.00

# %% [markdown]
# ![WhatsApp Image 2025-01-17 at 13.37.27_08c80120.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Q2

# %%
from scipy.optimize import linprog


c = [-50, -120]


A = [
    [7000, 2000],
    [10, 30]
]
b = [700000, 1200]
a_1=[[1,1]]
b_1=[100]

# %%
x_bounds = (0, None)
y_bounds = (0, None)



result = linprog(c, A_ub=A, b_ub=b, A_eq=a_1, b_eq=b_1, bounds=[x_bounds, y_bounds], method='highs')



if result.success:
    print(f"Optimal hectares for Wheat (x): {result.x[0]:.2f}")
    print(f"Optimal hectares for Barley (y): {result.x[1]:.2f}")
    print(f"Maximum profit: {-result.fun:.2f}")  # Negative because we minimized -Z
else:
    print("No solution found.")
# Out:
# Optimal hectares for Wheat (x): 90.00
# Optimal hectares for Barley (y): 10.00
# Maximum profit: 5700.00
